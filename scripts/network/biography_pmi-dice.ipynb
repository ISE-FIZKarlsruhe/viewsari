# %%
import datetime
import pandas as pd
from itertools import combinations
from collections import Counter
import math

# %%
df_ranges = pd.read_csv(
    '../../data/biographies/ranges/biography_page_ranges_II.csv')
df_data = pd.read_csv('../../data/references/1.csv')

# %%
df_ranges
# Out:
#                                                  Name Page Range
# 0                                               Berna        1-6
# 1                                              Duccio       7-12
# 2                                   Antonio Viniziano      13-20
# 3                                 Jacopo Di Casentino      21-26
# 4                                    Spinello Aretino      27-40
# 5                                   Gherardo Starnina      41-46
# 6                                               Lippo      47-52
# 7                                  Don Lorenzo Monaco      53-58
# 8                                      Taddeo Bartoli      59-64
# 9                                    Lorenzo Di Bicci      65-74
# 10            The Author's Preface to the Second Part      75-88
# 11          Jacopo della Quercia [Jacopo della Fonte]      89-98
# 12  Niccolò Aretino [Niccolò d'Arezzo or Niccolò d...     99-104
# 13                                              Dello    105-110
# 14                           Nanni D'Antonio Di Banco    111-116
# 15                                  Luca Della Robbia    117-128
# 16                                      Paolo Uccello    129-140
# 17  Lorenzo Ghiberti [Lorenzo di Cione Ghiberti or...    141-162
# 18                               Masolino Da Panicale    163-168
# 19                                     Parri Spinelli    169-180
# 20                                           Masaccio    181-192
# 21  Filippo Brunelleschi [Filippo di Ser Brunellesco]    193-236
# 22                                 Donato [Donatello]    237-256
# 23                              Michelozzo Michelozzi    257-272

# %%
df_ranges[['Start Page', 'End Page']] = df_ranges['Page Range'].str.extract(r'(\d+)-(\d+)')
# Convert start and end page numbers to integers
df_ranges['Start Page'] = pd.to_numeric(df_ranges['Start Page'], errors='coerce').astype('Int64')
df_ranges['End Page'] = pd.to_numeric(df_ranges['End Page'], errors='coerce').astype('Int64')

df_data['page'] = pd.to_numeric(df_data['page'], errors='coerce').astype('Int64')
df_data['paragraph'] = pd.to_numeric(df_data['paragraph'], errors='coerce').astype('Int64')

# %%
def expand_range(start_page, end_page):
    if pd.notna(start_page) and pd.notna(end_page):
        return list(range(int(start_page), int(end_page) + 1))
    else:
        return []

df_ranges['Page'] = df_ranges.apply(lambda row: expand_range(row['Start Page'], row['End Page']), axis=1)

df_expanded = df_ranges.explode('Page')

df_expanded
# Out:
#                      Name Page Range  Start Page  End Page Page
# 0                   Berna        1-6           1         6    1
# 0                   Berna        1-6           1         6    2
# 0                   Berna        1-6           1         6    3
# 0                   Berna        1-6           1         6    4
# 0                   Berna        1-6           1         6    5
# ..                    ...        ...         ...       ...  ...
# 23  Michelozzo Michelozzi    257-272         257       272  268
# 23  Michelozzo Michelozzi    257-272         257       272  269
# 23  Michelozzo Michelozzi    257-272         257       272  270
# 23  Michelozzo Michelozzi    257-272         257       272  271
# 23  Michelozzo Michelozzi    257-272         257       272  272
#
# [272 rows x 5 columns]

# %%
merged_df = pd.merge(df_data, df_expanded, how='left', left_on='page', right_on='Page')
merged_df.drop(columns=['Page'], inplace=True)

merged_df
# Out:
#      page             index_name    position  \
# 0       3                  Berna  (411, 538)
# 1       3                  Berna  (452, 454)
# 2       3                  Berna  (504, 506)
# 3       3                  Berna  (555, 557)
# 4       3                  Berna  (640, 642)
# ...   ...                    ...         ...
# 2540  270      Filarete, Antonio  (324, 327)
# 2541  271  Michelozzo Michelozzi    (14, 17)
# 2542  271  Michelozzo Michelozzi  (183, 193)
# 2543  271  Michelozzo Michelozzi  (224, 227)
# 2544  271  Michelozzo Michelozzi  (268, 270)
#
#                                               reference  paragraph  \
# 0     poor young Berna of Siena, who, although he di...          1
# 1                                                    he          1
# 2                                                    he          1
# 3                                                    he          1
# 4                                                    he          1
# ...                                                 ...        ...
# 2540                                                his        249
# 2541                                                his        249
# 2542                                         Michelozzo        249
# 2543                                                his        249
# 2544                                                 he        249
#
#                        Name Page Range  Start Page  End Page
# 0                     Berna        1-6           1         6
# 1                     Berna        1-6           1         6
# 2                     Berna        1-6           1         6
# 3                     Berna        1-6           1         6
# 4                     Berna        1-6           1         6
# ...                     ...        ...         ...       ...
# 2540  Michelozzo Michelozzi    257-272         257       272
# 2541  Michelozzo Michelozzi    257-272         257       272
# 2542  Michelozzo Michelozzi    257-272         257       272
# 2543  Michelozzo Michelozzi    257-272         257       272
# 2544  Michelozzo Michelozzi    257-272         257       272
#
# [2545 rows x 9 columns]

# %%
subdfs = {name: group for name, group in merged_df.groupby('Name')}

# %%
subdfs
# Out:
# {'Antonio Viniziano':    page          index_name      position          reference  paragraph  \
#  55   16  Viniziano, Antonio      (49, 52)                his          8
#  56   16  Viniziano, Antonio     (94, 101)            himself          8
#  57   16  Viniziano, Antonio    (123, 125)                 he          8
#  58   16  Viniziano, Antonio    (312, 314)                 he          8
#  59   16  Viniziano, Antonio    (394, 396)                 he          8
#  60   16  Viniziano, Antonio    (988, 995)            Antonio          8
#  61   16  Viniziano, Antonio  (1261, 1263)                 he          8
#  62   16  Viniziano, Antonio  (1485, 1487)                 he          8
#  63   16  Viniziano, Antonio  (1697, 1699)                 he          8
#  64   16  Viniziano, Antonio        (0, 7)            Antonio          9
#  65   16  Viniziano, Antonio    (289, 296)            Antonio          9
#  66   17  Viniziano, Antonio  (1091, 1098)            Antonio          9
#  67   17  Viniziano, Antonio  (1609, 1611)                 he          9
#  68   18  Viniziano, Antonio    (760, 762)                 he          9
#  69   18  Viniziano, Antonio    (849, 851)                 he          9
#  70   18  Viniziano, Antonio  (1471, 1478)            Antonio          9
#  71   18  Viniziano, Antonio  (1696, 1703)            Antonio          9
#  72   18  Viniziano, Antonio  (1971, 1973)                 he          9
#  73   19  Viniziano, Antonio      (76, 79)                him         10
#  74   19  Viniziano, Antonio    (126, 129)                him         10
#  75   19  Viniziano, Antonio    (155, 162)            Antonio         10
#  76   19  Viniziano, Antonio    (230, 232)                 he         10
#  77   19  Viniziano, Antonio    (405, 407)                 he         10
#  78   19  Viniziano, Antonio    (796, 811)    the same master         10
#  79   19  Viniziano, Antonio    (937, 939)                 he         10
#  80   19  Viniziano, Antonio  (1108, 1110)                 he         10
#  81   19  Viniziano, Antonio  (1139, 1146)            himself         10
#  82   19  Viniziano, Antonio  (1277, 1279)                 he         10
#  269  Gherardo Starnina      41-46          41        46
#  270  Gherardo Starnina      41-46          41        46
#  271  Gherardo Starnina      41-46          41        46
#  272  Gherardo Starnina      41-46          41        46
#  273  Gherardo Starnina      41-46          41        46
#  274  Gherardo Starnina      41-46          41        46
#  275  Gherardo Starnina      41-46          41        46
#  276  Gherardo Starnina      41-46          41        46
#  277  Gherardo Starnina      41-46          41        46
#  278  Gherardo Starnina      41-46          41        46
#  279  Gherardo Starnina      41-46          41        46  ,
#  'Jacopo Di Casentino':     page            index_name      position            reference  paragraph  \
#  98    23                Giotto      (52, 58)               Giotto         12
#  99    23                Giotto      (63, 66)                  his         12
#  100   23                Giotto    (402, 408)               Giotto         12
#  101   23         Gaddi, Taddeo    (413, 419)               Taddeo         12
#  102   23         Gaddi, Taddeo    (663, 675)         Taddeo Gaddi         12
#  103   23         Gaddi, Taddeo    (683, 689)               Taddeo         12
#  104   23         Gaddi, Taddeo    (941, 960)  Taddeo their master         12
#  105   23  Casentino, Jacopo di    (735, 737)                   he         12
#  106   23  Casentino, Jacopo di    (807, 809)                   he         12
#  107   23  Casentino, Jacopo di    (843, 850)              himself         12
#  108   23  Casentino, Jacopo di    (962, 964)                   he         12
#  109   23  Casentino, Jacopo di  (1239, 1245)               Jacopo         12
#  110   23  Casentino, Jacopo di  (1265, 1267)                   he         12
#  111   24  Casentino, Jacopo di      (20, 26)               Jacopo         13
#  112   24  Casentino, Jacopo di      (64, 66)                   he         13
#  113   24  Casentino, Jacopo di    (147, 149)                   he         13
#  114   24  Casentino, Jacopo di    (157, 164)              himself         13
#  115   24  Casentino, Jacopo di    (375, 377)                   he         13
#  116   24  Casentino, Jacopo di    (628, 630)                   he         13
#  117   24  Casentino, Jacopo di    (762, 764)                   he         13
#  118   24  Casentino, Jacopo di    (879, 881)                   he         13
#  119   24  Casentino, Jacopo di  (1237, 1239)                   he         13
#  120   25  Casentino, Jacopo di        (1, 7)               Jacopo         14
#  121   25  Casentino, Jacopo di    (511, 517)               Jacopo         14
#  122   25  Casentino, Jacopo di      (54, 60)               Jacopo         15
#  123   25  Casentino, Jacopo di      (80, 83)                  his         15
#  124   25  Casentino, Jacopo di    (352, 354)                   he         15
#  125   25  Casentino, Jacopo di    (435, 438)                  his         15
#  126   25  Casentino, Jacopo di    (475, 477)                   he         15
#  127   25     Aretino, Spinello    (488, 504)     Spinello Aretino         15
#  128   25     Aretino, Spinello    (552, 555)                  him         15
#  129   25     Aretino, Spinello    (577, 585)             Spinello         15
#  130   25       Daddi, Bernardo    (639, 642)                  his         15
#  131   25       Daddi, Bernardo    (725, 728)                  his         15
#  132   25       Daddi, Bernardo    (779, 781)                   he         15
#  133   25       Daddi, Bernardo    (803, 806)                  his         15
#  134   25       Daddi, Bernardo    (837, 840)                  him         15
#  135   25       Daddi, Bernardo    (908, 916)             Bernardo         15
#  136   25       Daddi, Bernardo  (1210, 1212)                   he         15
#  137   25  Casentino, Jacopo di      (17, 23)               Jacopo         16
#              reference  paragraph                                     Name  \
#  448     Andrea Pisano         64  The Author's Preface to the Second Part
#  449               his         64  The Author's Preface to the Second Part
#  450               his         64  The Author's Preface to the Second Part
#  451            Giotto         65  The Author's Preface to the Second Part
#  452            Giotto         65  The Author's Preface to the Second Part
#  453               him         65  The Author's Preface to the Second Part
#  454               his         65  The Author's Preface to the Second Part
#  455            Giotto         65  The Author's Preface to the Second Part
#  456               his         65  The Author's Preface to the Second Part
#  457               his         65  The Author's Preface to the Second Part
#  458               him         65  The Author's Preface to the Second Part
#  459                he         65  The Author's Preface to the Second Part
#  460                he         65  The Author's Preface to the Second Part
#  461                he         65  The Author's Preface to the Second Part
#  462               his         65  The Author's Preface to the Second Part
#  463                he         65  The Author's Preface to the Second Part
#  464               him         65  The Author's Preface to the Second Part
#  465                he         65  The Author's Preface to the Second Part
#  466           himself         65  The Author's Preface to the Second Part
#  467               his         65  The Author's Preface to the Second Part
#  468               his         65  The Author's Preface to the Second Part
#  469                he         65  The Author's Preface to the Second Part
#  470               him         65  The Author's Preface to the Second Part
#  471            Giotto         65  The Author's Preface to the Second Part
#  472            Giotto         65  The Author's Preface to the Second Part
#  473               his         65  The Author's Preface to the Second Part
#  474            Giotto         65  The Author's Preface to the Second Part
#  475  Spinello Aretino         65  The Author's Preface to the Second Part
#  476               his         65  The Author's Preface to the Second Part
#  477               his         66  The Author's Preface to the Second Part
#  478               his         66  The Author's Preface to the Second Part
#  479           Filippo         66  The Author's Preface to the Second Part
#  480  Lorenzo Ghiberti         67  The Author's Preface to the Second Part
#  481                he         67  The Author's Preface to the Second Part
#  482               his         67  The Author's Preface to the Second Part
#
#      Page Range  Start Page  End Page
#  448      75-88          75        88
#  449      75-88          75        88
#  450      75-88          75        88
#  451      75-88          75        88
#  452      75-88          75        88
#  453      75-88          75        88
#  454      75-88          75        88
#  455      75-88          75        88
#  456      75-88          75        88
#  457      75-88          75        88
#  458      75-88          75        88
#  459      75-88          75        88
#  460      75-88          75        88
#  461      75-88          75        88
#  462      75-88          75        88
#  463      75-88          75        88
#  464      75-88          75        88
#  465      75-88          75        88
#  466      75-88          75        88
#  467      75-88          75        88
#  468      75-88          75        88
#  469      75-88          75        88
#  470      75-88          75        88
#  471      75-88          75        88
#  472      75-88          75        88
#  473      75-88          75        88
#  474      75-88          75        88
#  475      75-88          75        88
#  476      75-88          75        88
#  477      75-88          75        88
#  478      75-88          75        88
#  479      75-88          75        88
#  480      75-88          75        88
#  481      75-88          75        88
#  482      75-88          75        88  }

# %%
def dice_coefficient(artist1, artist2, df):
    # Group the dataframe by paragraph and get the set of artists for each paragraph
    grouped = df.groupby('paragraph').agg({'index_name': set, 'page': 'first'})

    # Count the number of paragraphs where each artist appears
    artist1_paragraphs = Counter()
    artist2_paragraphs = Counter()
    shared_paragraphs = []

    for paragraph, row in grouped.iterrows():
        artists = row['index_name']
        page = row['page']
        if artist1 in artists and artist2 in artists:
            shared_paragraphs.append((page, paragraph))
        if artist1 in artists:
            artist1_paragraphs[paragraph] += 1
        if artist2 in artists:
            artist2_paragraphs[paragraph] += 1

    # Calculate the Dice coefficient
    numerator = 2 * len(shared_paragraphs)
    denominator = sum(artist1_paragraphs.values()) + sum(artist2_paragraphs.values())
    dice = numerator / denominator if denominator > 0 else 0
    return dice, shared_paragraphs

# %%
def calculate_dice_coefficients(df):
    artist_names = df['index_name'].unique()
    dice_coefficients = {}

    # Iterate over all combinations of unique artist names
    for artist1, artist2 in combinations(artist_names, 2):
        # Calculate the Dice coefficient for the pair
        dice, shared_paragraphs = dice_coefficient(artist1, artist2, df)
        # Store the coefficient and shared paragraphs in the dictionary
        dice_coefficients[(artist1, artist2)] = {'coefficient': dice, 'shared_paragraphs': shared_paragraphs}

    return dice_coefficients

# %%
for name, sub_df in subdfs.items():
    print(f"Name: {name}")
    dice_coefficients = calculate_dice_coefficients(sub_df)
    # Create a list to store the rows of the DataFrame
    rows = []
    dice_activity = "dice_activity_biography-level_" + str(datetime.date.today())
    start_time = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
    # Populate the list with the calculated values
    for pair, info in dice_coefficients.items():
        artist1, artist2 = pair
        dice_coefficient_value = info['coefficient']
        if dice_coefficient_value > 0.0:  # Filter out values <= 0.0
            end_time = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
            shared_paragraphs = info['shared_paragraphs']
            for page, paragraph in shared_paragraphs:
                rows.append(
                    {'artist1': artist1, 'artist2': artist2, 'dice_coefficient': dice_coefficient_value, 'page': page,
                     'paragraph': paragraph, 'activity': dice_activity, 'start': start_time, 'end': end_time})
            # Create a DataFrame from the list of rows
            result_df = pd.DataFrame(rows)
            # Save the DataFrame to a CSV file named after the artist
            result_df.to_csv(f"../../data/biographies/dice/{name}_dice_coefficients.csv", index=False)
# Out:
# Name: Antonio Viniziano
# Name: Berna
# Name: Dello
# Name: Don Lorenzo Monaco
# Name: Donato [Donatello]
# Name: Duccio
# Name: Filippo Brunelleschi [Filippo di Ser Brunellesco]
# Name: Gherardo Starnina
# Name: Jacopo Di Casentino
# Name: Jacopo della Quercia [Jacopo della Fonte]
# Name: Lippo
# Name: Lorenzo Di Bicci
# Name: Lorenzo Ghiberti [Lorenzo di Cione Ghiberti or Lorenzo di Bartoluccio Ghiberti]
# Name: Luca Della Robbia
# Name: Masaccio
# Name: Masolino Da Panicale
# Name: Michelozzo Michelozzi
# Name: Nanni D'Antonio Di Banco
# Name: Niccolò Aretino [Niccolò d'Arezzo or Niccolò di Piero Lamberti]
# Name: Paolo Uccello
# Name: Parri Spinelli
# Name: Spinello Aretino
# Name: Taddeo Bartoli
# Name: The Author's Preface to the Second Part

# %%
def calculate_pmi(artist1, artist2, df):
    # Group the dataframe by paragraph and get the set of artists for each paragraph
    grouped = df.groupby(['page', 'paragraph'])['index_name'].apply(set)

    # Count the number of paragraphs where each artist appears
    artist1_paragraphs = Counter()
    artist2_paragraphs = Counter()
    shared_paragraphs = Counter()
    total_paragraphs = len(grouped)

    for (page, paragraph), artists in grouped.items():
        if artist1 in artists and artist2 in artists:
            shared_paragraphs[(page, paragraph)] += 1
        if artist1 in artists:
            artist1_paragraphs[(page, paragraph)] += 1
        if artist2 in artists:
            artist2_paragraphs[(page, paragraph)] += 1

    # Calculate the PMI
    p_artist1 = sum(artist1_paragraphs.values()) / total_paragraphs
    p_artist2 = sum(artist2_paragraphs.values()) / total_paragraphs
    p_both = sum(shared_paragraphs.values()) / total_paragraphs

    # Handle zero probability cases
    if p_artist1 == 0 or p_artist2 == 0 or p_both == 0:
        pmi = float('-inf')
    else:
        pmi = math.log2(p_both / (p_artist1 * p_artist2))
    return pmi, shared_paragraphs

# %%
def calculate_pmi_values(df):
    artist_names = df['index_name'].unique()
    pmi_values = {}

    # Iterate over all combinations of unique artist names
    for artist1, artist2 in combinations(artist_names, 2):
        # Calculate the PMI and get shared pages and paragraphs for the pair
        pmi, shared_pages_paragraphs = calculate_pmi(artist1, artist2, df)
        # Store the PMI value and shared pages and paragraphs in the dictionary
        pmi_values[(artist1, artist2)] = {'PMI': pmi, 'Shared_pages_paragraphs': shared_pages_paragraphs}

    return pmi_values

# %%
for name, sub_df in subdfs.items():
    pmi_values = calculate_pmi_values(sub_df)
    
    pmi_activity = "pmi_activity_biography-level_" + str(datetime.date.today())
    start_time = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
    
    # Create a list to store the rows of the DataFrame
    rows = []
    # Populate the list with the calculated values
    for pair, data in pmi_values.items():
        artist1, artist2 = pair
        pmi = data['PMI']
        if pmi > 0:
            end_time = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
            shared_pages_paragraphs = data['Shared_pages_paragraphs']
            for (page, paragraph), count in shared_pages_paragraphs.items():
                rows.append({'artist1': artist1, 'artist2': artist2, 'shared_count': count, 'pmi_score': pmi, 'page': page,
                     'paragraph': paragraph, 'activity': pmi_activity, 'start': start_time, 'end': end_time})
            # Create a DataFrame from the list of rows
            result_df = pd.DataFrame(rows)
            # Save the DataFrame to a CSV file named after the artist
            result_df.to_csv(f"../../data/biographies/pmi/{name}_pmi_values.csv", index=False)
# Out:
# Name: Antonio Viniziano
# Name: Berna
# Name: Dello
# Name: Don Lorenzo Monaco
# Name: Donato [Donatello]
# Name: Duccio
# Name: Filippo Brunelleschi [Filippo di Ser Brunellesco]
# Name: Gherardo Starnina
# Name: Jacopo Di Casentino
# Name: Jacopo della Quercia [Jacopo della Fonte]
# Name: Lippo
# Name: Lorenzo Di Bicci
# Name: Lorenzo Ghiberti [Lorenzo di Cione Ghiberti or Lorenzo di Bartoluccio Ghiberti]
# Name: Luca Della Robbia
# Name: Masaccio
# Name: Masolino Da Panicale
# Name: Michelozzo Michelozzi
# Name: Nanni D'Antonio Di Banco
# Name: Niccolò Aretino [Niccolò d'Arezzo or Niccolò di Piero Lamberti]
# Name: Paolo Uccello
# Name: Parri Spinelli
# Name: Spinello Aretino
# Name: Taddeo Bartoli
# Name: The Author's Preface to the Second Part
