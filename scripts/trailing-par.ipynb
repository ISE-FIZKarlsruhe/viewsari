# %%
import pandas as pd
import glob
# Out:
# /var/folders/9j/98p9mwr15n9bth0p8pz0pfym0000gn/T/ipykernel_2660/839084525.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
for file in glob.glob('../data/volumes/*.csv'):
    df = pd.read_csv(file)
    var = df[df['pages'].str.contains(" ")]
    print(var)
# Out:
#         pages  paragraph_id                                               text
# 5         7 8             6  Having thus departed from Carrara, Tribolo, on...
# 15      15 16            16  Having heard of the Duke's death, Tribolo cond...
# 25   22 23 24            26  Having then set his hand to the fountain of th...
# 36      30 31            37  In like manner, in the year when there was bor...
# 38      33 34            39  Now it was the custom in the city of Florence ...
# 109     86 87           110  Even so, if Baccio and Giuliano, being engaged...
# 114     91 92           115  Baccio, on his part, also set to work to make ...
# 156   125 126           157  Giorgio being afterwards summoned to Venice at...
# 251   187 188           252  Not long afterwards he returned one summer to ...
# 255   191 192           256  While Simone was engaged in finishing this wel...
# 292   218 219           293  Thereupon Pope Clement VII, proposing to make ...
# ...
